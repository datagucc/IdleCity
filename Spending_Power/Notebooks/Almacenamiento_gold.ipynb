# %% [markdown]
# # 🌍 Open-Meteo - Data Engineering Project
#
# In the previous **Silver Layer**, we cleaned and standardized the raw weather data, ensuring type consistency, proper formatting, and reliable structure.
#
# Now, in the **Gold Layer**, we elevate our data to a **business-level view** — transforming clean technical data into **actionable insights**. This layer is designed to support **reporting**, **analytics**, and **decision-making**.
#
#
#
# ### 🎯 Objectives
#
# We will perform the following transformations:
#
# - **Cross-table merging**:
#   - Join **weather condition codes** with the **geolocation** table.
#   - Enrich weather observations with geographical and categorical context.
#
# - **Aggregations and Grouping**:
#   - Compute **global** and **per-city** historical weather statistics.
#   - Generate **monthly** and **yearly** temperature summaries.
#   - Evaluate **forecast accuracy** by comparing forecasted vs. actual historical data (*future implementation*).
#
# - **Statistical Analysis** *(optional/advanced)*:
#   - Explore correlations (e.g., between **latitude/longitude**, **elevation**, and **weather variables**)(*future implementation*).
#
#
#
#
# ### 📦 Available Silver Tables
#
# We will use the following inputs from the Silver Layer:
#
# - `📍 geolocation` — Cleaned metadata for cities and coordinates.
# - `🌤 weathercode` — Descriptions and classification of weather conditions.
# - `☁ current_weather` — Real-time conditions at time of data collection.
# - `📆 forecast_daily_weather` — Daily-level weather predictions.
# - `🕒 forecast_hourly_weather` — Hourly-level weather predictions.
# - `📈 historical_weather` — Actual observed weather data.

# %%
#Import libraries
import sys
import os
#to get summarized informations about df, just used for investigation
from ydata_profiling import ProfileReport
# Add the path to the modules directory
my_current_loc = os.getcwd()
my_modules_dir = "/Users/focus_profond/UTN/Data_engineering/proyecto/UTN_data_engineering_project/Entrega_Final/Modules"
os.chdir(my_modules_dir)

#Importing personal modules
from DF_functions import *
from openmeteo_API import *

#Returning to the main directory
#my_main_dir = "/Users/focus_profond/UTN/Data_engineering/proyecto/UTN_data_engineering_project/Entrega"
os.chdir(my_current_loc)
os.chdir('../')
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# Module exécuté dans : /Users/focus_profond/UTN/Data_engineering/proyecto/UTN_data_engineering_project/utn_env/bin/python

# %% [markdown]
# ### 🌐 3.1 Merge Weather Tables with Geolocation & Weather Descriptions
#
# In this step, we will enrich each weather dataset — **Current Weather**, **Forecast Daily**, **Forecast Hourly**, and **Historical Weather** — with geographical and descriptive context.
#
# 📊 The goal is to create **business-level weather tables**, combining:
# - **Raw meteorological metrics** (temperature, humidity, precipitation, etc.)
# - **Geographical information** (city name, country, coordinates, elevation, etc.)
# - **Semantic descriptions** (decoded weather codes)
#
# 🔗 We will perform a two-step join:
# 1. Merge the weather data with the **geolocation table** using the location identifier.
# 2. Merge the result with the **weather code table** using the `weathercode` column.
#
# This will allow us to produce rich datasets ready for:
# - **Business analysis**
# - **Visualization**
# - **Advanced correlation or predictive modeling**

# %% [markdown]
# ##### 🌐 3.1.1. Current weather

# %%
path1 = 'Data/Silver/OpenMeteo/Current'
path2 = 'Data/Silver/OpenMeteo/Others/Geolocation'
path3 = 'Data/Silver/OpenMeteo/Others/WeatherCode'
type_merge = 'left'
df1_keys = ['latitude','longitude']
df2_keys = ['latitude','longitude']
df2_columns = ['elevation_m','timezone','population','country','latitude','longitude']

df1a_keys = ['weather_code']
df2a_keys = ['weather_code']
df2a_columns = ['weather_code','description']

#cross joining the current weather data with the geolocation data
df_current = merging_df(path1,path2,type_merge,df1_keys,df2_keys,df2_columns)
#cross joining the current weather data with the weather code
df_current_full = merging_df(df_current,path3,type_merge,df1a_keys,df2a_keys,df2a_columns)
my_dt = df_current_full

# Add new columns based on temperature thresholds
my_dt['warm_enough'] = my_dt['temperature_2m_C'] > 23
my_dt['too_cold'] = my_dt['temperature_2m_C'] < 10

# %%
#STORING THE DATA
name_folder = 'Data/Gold/OpenMeteo/Current'
predicate = "target.Date = source.Date AND target.Time = source.Time AND target.City = source.City"
partition_cols = "Date"
save_new_data_as_delta(my_dt,name_folder,predicate = predicate, partition_cols=partition_cols, layer = 'Gold', source = 'open-meteo-current',author='Augustin')

# Verifying the data of the silver layer
my_dt = DeltaTable(name_folder).to_pandas()
my_dt.head()
# Out:
#         date   time          city  longitude  latitude  surface_pressure_hPa  \
# 0 2025-04-12  23:39     Barcelona    2.15899  41.38879           1015.924927
# 1 2025-04-12  23:39           Biu   12.19458  10.61285            926.992493
# 2 2025-04-12  23:39        Boston  -71.05977  42.35843           1013.312744
# 3 2025-04-12  23:39      Brussels    4.34878  50.85045           1024.516846
# 4 2025-04-12  23:39  Buenos Aires  -58.37723 -34.61315           1016.168091
#
#    snowfall_cm  is_day  wind_gusts_10m  pressure_msl_hPa  ...  weather_code  \
# 0          0.0    True       31.680000       1021.200012  ...             2
# 1          0.0   False       18.359999       1010.099976  ...             0
# 2          0.0   False       47.519997       1015.700012  ...             3
# 3          0.0    True       28.080000       1027.800049  ...             3
# 4          0.0    True       37.439999       1018.400024  ...             3
#
#    precipitation_mm  temperature_2m_C  warm_enough  too_cold  elevation_m  \
# 0               0.0         16.950001        False     False         15.0
# 1               0.0         25.600000         True     False        762.0
# 2               0.0          2.622000        False      True         14.0
# 3               0.0         15.050000        False     False         28.0
# 4               0.0         22.650000        False     False         31.0
#
#                          timezone population        country    description
# 0                   Europe/Madrid    1621537          Spain  Partly cloudy
# 1                    Africa/Lagos      95005        Nigeria      Clear sky
# 2                America/New_York     667137  United States       Overcast
# 3                 Europe/Brussels    1019022        Belgium       Overcast
# 4  America/Argentina/Buenos_Aires   13076300      Argentina       Overcast
#
# [5 rows x 27 columns]

# %% [markdown]
# ##### 🌐 3.1.2. Forecast daily weather

# %%
path1 = 'Data/Silver/OpenMeteo/Forecast/Daily'
path2 = 'Data/Silver/OpenMeteo/Others/Geolocation'
path3 = 'Data/Silver/OpenMeteo/Others/WeatherCode'
type_merge = 'left'
df1_keys = ['latitude','longitude']
df2_keys = ['latitude','longitude']
df2_columns = ['elevation_m','timezone','population','country','latitude','longitude']

df1a_keys = ['weather_code']
df2a_keys = ['weather_code']
df2a_columns = ['weather_code','description']

#cross joining the forecast daily weather data with the geolocation data 
df_current = merging_df(path1,path2,type_merge,df1_keys,df2_keys,df2_columns)
#cross joining the forecast daily weather with the weather code 
df_current_full = merging_df(df_current,path3,type_merge,df1a_keys,df2a_keys,df2a_columns)

my_dt = df_current_full

# Add new columns based on conditions
my_dt['warm_enough'] = my_dt['temperature_2m_max_C'] > 23
my_dt['too_cold'] = my_dt['temperature_2m_min_C'] < 10
my_dt['sufficient_sunshine'] = my_dt['sunshine_duration_hours'] > 6

my_dt.head()
# Out:
#   requested_date       city              forecast_day weather_code  \
# 0     2025-04-12  Barcelona 2025-04-15 00:00:00+00:00           95
# 1     2025-04-12  Barcelona 2025-04-16 00:00:00+00:00           80
# 2     2025-04-12  Barcelona 2025-04-17 00:00:00+00:00            3
# 3     2025-04-12    Chicago 2025-04-18 00:00:00+00:00           51
# 4     2025-04-12     La Paz 2025-04-18 00:00:00+00:00            3
#
#    apparent_temperature_min_C  sunshine_duration_seconds  rain_sum_mm  \
# 0                   10.728018               43362.718750          0.0
# 1                   10.020213               29489.005859          0.6
# 2                    5.977081               44506.859375          0.0
# 3                    2.674845               30807.576172          0.3
# 4                   17.340675               43364.820312          0.0
#
#    precipitation_probability_max_inPercent  shortwave_radiation_sum_MJm2  \
# 0                                     68.0                     21.540001
# 1                                     88.0                     14.970000
# 2                                     15.0                     23.420000
# 3                                     48.0                     12.810000
# 4                                      2.0                     26.750000
#
#    temperature_2m_max_C  ...  daylight_duration_minutes  \
# 0             20.271000  ...                 800.527710
# 1             17.821001  ...                 803.131897
# 2             20.082500  ...                 805.713745
# 3             20.925999  ...                 809.530457
# 4             32.548000  ...                 767.507751
#
#    daylight_duration_hours  elevation_m          timezone  population  \
# 0                13.342129         15.0     Europe/Madrid     1621537
# 1                13.385531         15.0     Europe/Madrid     1621537
# 2                13.428562         15.0     Europe/Madrid     1621537
# 3                13.492174        179.0   America/Chicago     2720546
# 4                12.791796         47.0  America/Mazatlan      215178
#
#          country              description  warm_enough  too_cold  \
# 0          Spain                      NaN        False     False
# 1          Spain      Rain showers slight        False     False
# 2          Spain                 Overcast        False      True
# 3  United States  Drizzle light intensity        False      True
# 4         Mexico                 Overcast         True     False
#
#    sufficient_sunshine
# 0                 True
# 1                 True
# 2                 True
# 3                 True
# 4                 True
#
# [5 rows x 37 columns]

# %%
#STORING THE DATA
name_folder = 'Data/Gold/OpenMeteo/Forecast/Daily'
predicate = """target.requested_date = source.requested_date AND target.city = source.city and target.forecast_day = source.forecast_day """
partition_cols = ["requested_date"]

save_new_data_as_delta(my_dt,name_folder,predicate= predicate, partition_cols=partition_cols,layer = 'Gold', source= 'open-meteo-forecast-daily', author ='Augustin')

# Verifying the data of the gold layer
my_dt = DeltaTable(name_folder).to_pandas()
my_dt.head()
# Out:
#   requested_date city              forecast_day weather_code  \
# 0     2025-04-12  Biu 2025-04-12 00:00:00+00:00            3
# 1     2025-04-12  Biu 2025-04-14 00:00:00+00:00            3
# 2     2025-04-12  Biu 2025-04-15 00:00:00+00:00            3
# 3     2025-04-12  Biu 2025-04-16 00:00:00+00:00            2
# 4     2025-04-12  Biu 2025-04-17 00:00:00+00:00            3
#
#    apparent_temperature_min_C  sunshine_duration_seconds  rain_sum_mm  \
# 0                   21.073042               39960.453125          0.0
# 1                   18.443285               41903.117188          0.0
# 2                   22.393799               39693.480469          0.0
# 3                   23.345686               42075.976562          0.0
# 4                   26.679255               42106.542969          0.0
#
#    precipitation_probability_max_inPercent  shortwave_radiation_sum_MJm2  \
# 0                                      0.0                     26.219999
# 1                                      0.0                     27.799999
# 2                                      3.0                     27.260000
# 3                                     10.0                     28.160000
# 4                                      0.0                     25.870001
#
#    temperature_2m_max_C  ...  daylight_duration_minutes  \
# 0             36.323498  ...                 740.483826
# 1             37.423500  ...                 741.623596
# 2             38.573498  ...                 742.186218
# 3             38.823498  ...                 742.743408
# 4             38.973499  ...                 743.295532
#
#    daylight_duration_hours  warm_enough  too_cold  sufficient_sunshine  \
# 0                12.341397         True     False                 True
# 1                12.360393         True     False                 True
# 2                12.369770         True     False                 True
# 3                12.379057         True     False                 True
# 4                12.388259         True     False                 True
#
#    elevation_m      timezone  population  country    description
# 0        762.0  Africa/Lagos       95005  Nigeria       Overcast
# 1        762.0  Africa/Lagos       95005  Nigeria       Overcast
# 2        762.0  Africa/Lagos       95005  Nigeria       Overcast
# 3        762.0  Africa/Lagos       95005  Nigeria  Partly cloudy
# 4        762.0  Africa/Lagos       95005  Nigeria       Overcast
#
# [5 rows x 37 columns]

# %% [markdown]
# FORECAST HOURLY WEATHER  WITH GEOLOC AND WEATHERCODE

# %% [markdown]
# ##### 🌐 3.1.3. Forecast hourly weather

# %%
path1 = 'Data/Silver/OpenMeteo/Forecast/Hourly'
path2 = 'Data/Silver/OpenMeteo/Others/Geolocation'
path3 = 'Data/Silver/OpenMeteo/Others/WeatherCode'
type_merge = 'left'
df1_keys = ['latitude','longitude']
df2_keys = ['latitude','longitude']
df2_columns = ['elevation_m','timezone','population','country','latitude','longitude']

df1a_keys = ['weather_code']
df2a_keys = ['weather_code']
df2a_columns = ['weather_code','description']

#cross joining the forecast hourly weather data with the geolocation data 
df_current = merging_df(path1,path2,type_merge,df1_keys,df2_keys,df2_columns)
#cross joining the forecast hourly weather with the weather code
df_current_full = merging_df(df_current,path3,type_merge,df1a_keys,df2a_keys,df2a_columns)
my_dt = df_current_full

# Add new columns based on conditions
my_dt['warm_enough'] = my_dt['temperature_2m_C'] > 23
my_dt['too_cold'] = my_dt['temperature_2m_C'] < 10
my_dt['too_much_cloud'] = my_dt['cloud_cover_inPercent'] > 65
my_dt.head()
# Out:
#   requested_date            city forecast_date forecast_hour  longitude  \
# 0     2025-04-12  Rio de Janeiro    2025-04-13         20:00  -43.18223
# 1     2025-04-12       Barcelona    2025-04-10         12:00    2.15899
# 2     2025-04-12       Barcelona    2025-04-10         15:00    2.15899
# 3     2025-04-12       Barcelona    2025-04-11         00:00    2.15899
# 4     2025-04-12       Barcelona    2025-04-11         01:00    2.15899
#
#    latitude  soil_moisture_27_to_81cm_m3m3  soil_moisture_9_to_27cm_m3m3  \
# 0 -22.90642                          0.373                         0.350
# 1  41.38879                          0.317                         0.286
# 2  41.38879                          0.317                         0.286
# 3  41.38879                          0.317                         0.285
# 4  41.38879                          0.316                         0.285
#
#    soil_moisture_3_to_9cm_m3m3  soil_moisture_1_to_3cm_m3m3  ...  \
# 0                        0.328                        0.306  ...
# 1                        0.272                        0.265  ...
# 2                        0.271                        0.261  ...
# 3                        0.269                        0.264  ...
# 4                        0.269                        0.264  ...
#
#    relative_humidity_2m_inPercent  temperature_2m_C  elevation_m  \
# 0                            62.0         27.575998         12.0
# 1                            74.0         17.371000         15.0
# 2                            73.0         17.171001         15.0
# 3                            97.0         12.321000         15.0
# 4                            98.0         11.821000         15.0
#
#             timezone  population  country    description  warm_enough  \
# 0  America/Sao_Paulo     6023699   Brazil   Mainly clear         True
# 1      Europe/Madrid     1621537    Spain  Partly cloudy        False
# 2      Europe/Madrid     1621537    Spain  Partly cloudy        False
# 3      Europe/Madrid     1621537    Spain            Fog        False
# 4      Europe/Madrid     1621537    Spain            Fog        False
#
#    too_cold  too_much_cloud
# 0     False           False
# 1     False            True
# 2     False           False
# 3     False           False
# 4     False            True
#
# [5 rows x 56 columns]

# %%
#STORING THE DATA
name_folder = 'Data/Gold/OpenMeteo/Forecast/Hourly'
partition_cols = ["requested_date"]
predicate = """target.requested_date = source.requested_date  AND target.city = source.city AND target.forecast_date = source.forecast_date and target.forecast_hour = source.forecast_hour """

upsert_data_as_delta(my_dt,name_folder,predicate= predicate, partition_cols=partition_cols, layer = 'Gold', source= 'open-meteo-forecast-hourly', author ='Augustin')

# Verifying the data of the bronze layer
my_dt = DeltaTable(name_folder).to_pandas()
my_dt.head()
# Out:
#   requested_date city forecast_date forecast_hour  longitude  latitude  \
# 0     2025-04-12  Biu    2025-04-12         11:00   12.19458  10.61285
# 1     2025-04-12  Biu    2025-04-12         15:00   12.19458  10.61285
# 2     2025-04-12  Biu    2025-04-13         05:00   12.19458  10.61285
# 3     2025-04-12  Biu    2025-04-13         08:00   12.19458  10.61285
# 4     2025-04-12  Biu    2025-04-14         11:00   12.19458  10.61285
#
#    soil_moisture_27_to_81cm_m3m3  soil_moisture_9_to_27cm_m3m3  \
# 0                          0.156                         0.128
# 1                          0.156                         0.127
# 2                          0.156                         0.127
# 3                          0.156                         0.126
# 4                          0.155                         0.124
#
#    soil_moisture_3_to_9cm_m3m3  soil_moisture_1_to_3cm_m3m3  ...  \
# 0                        0.110                        0.085  ...
# 1                        0.110                        0.082  ...
# 2                        0.107                        0.077  ...
# 3                        0.107                        0.077  ...
# 4                        0.103                        0.071  ...
#
#    relative_humidity_2m_inPercent  temperature_2m_C  warm_enough  too_cold  \
# 0                            12.0         34.073498         True     False
# 1                            11.0         35.973499         True     False
# 2                            28.0         22.473499        False     False
# 3                            19.0         27.723499         True     False
# 4                            13.0         35.473499         True     False
#
#    too_much_cloud  elevation_m      timezone  population  country  description
# 0           False        762.0  Africa/Lagos       95005  Nigeria    Clear sky
# 1           False        762.0  Africa/Lagos       95005  Nigeria    Clear sky
# 2           False        762.0  Africa/Lagos       95005  Nigeria    Clear sky
# 3           False        762.0  Africa/Lagos       95005  Nigeria    Clear sky
# 4           False        762.0  Africa/Lagos       95005  Nigeria    Clear sky
#
# [5 rows x 56 columns]

# %% [markdown]
# ##### 🌐 3.1.4. Historical daily weather

# %%
path1 = 'Data/Silver/OpenMeteo/Historical/Daily'
path2 = 'Data/Silver/OpenMeteo/Others/Geolocation'
path3 = 'Data/Silver/OpenMeteo/Others/WeatherCode'
type_merge = 'left'
df1_keys = ['latitude','longitude']
df2_keys = ['latitude','longitude']
df2_columns = ['elevation_m','timezone','population','country','latitude','longitude']

df1a_keys = ['weather_code']
df2a_keys = ['weather_code']
df2a_columns = ['weather_code','description']

#cross joining the historical daily weather data with the geolocation data
df_current = merging_df(path1,path2,type_merge,df1_keys,df2_keys,df2_columns)
#cross joining the historical daily weather data with the weather code
df_current_full = merging_df(df_current,path3,type_merge,df1a_keys,df2a_keys,df2a_columns)
my_dt = df_current_full

# Add new columns based on conditions
my_dt['warm_enough'] = my_dt['temperature_2m_max_C'] > 23
my_dt['too_cold'] = my_dt['temperature_2m_min_C'] < 10
my_dt['sufficient_sunshine'] = my_dt['sunshine_duration_hours'] > 6

my_dt.head()
# Out:
#         city historical_date historical_year historical_month historical_day  \
# 0  Barcelona      2013-01-18            2013               01            Fri
# 1  Barcelona      2013-01-26            2013               01            Sat
# 2  Barcelona      2013-01-24            2013               01            Thu
# 3  Barcelona      2013-02-15            2013               02            Fri
# 4  Barcelona      2013-02-03            2013               02            Sun
#
#    longitude  latitude  wind_direction_10m_dominant_deg  \
# 0    2.15899  41.38879                       245.865112
# 1    2.15899  41.38879                        35.972466
# 2    2.15899  41.38879                       299.295288
# 3    2.15899  41.38879                       211.914871
# 4    2.15899  41.38879                       327.231506
#
#    precipitation_hours_h  precipitation_sum  ...  daylight_duration_minutes  \
# 0                    9.0                2.4  ...                 576.679810
# 1                    4.0                1.2  ...                 592.010498
# 2                    3.0                0.6  ...                 587.966187
# 3                    0.0                0.0  ...                 639.140747
# 4                    0.0                0.0  ...                 609.381714
#
#    daylight_duration_hours  warm_enough  too_cold  sufficient_sunshine  \
# 0                 9.611330        False      True                False
# 1                 9.866841        False      True                 True
# 2                 9.799437        False      True                 True
# 3                10.652346        False      True                 True
# 4                10.156362        False      True                 True
#
#    elevation_m       timezone  population  country                 description
# 0         15.0  Europe/Madrid     1621537    Spain     Drizzle light intensity
# 1         15.0  Europe/Madrid     1621537    Spain  Drizzle moderate intensity
# 2         15.0  Europe/Madrid     1621537    Spain     Drizzle light intensity
# 3         15.0  Europe/Madrid     1621537    Spain                    Overcast
# 4         15.0  Europe/Madrid     1621537    Spain                Mainly clear
#
# [5 rows x 36 columns]

# %%
#STORING THE DATA
name_folder = 'Data/Gold/OpenMeteo/Historical/Daily'
predicate = """target.city = source.city AND target.historical_date = source.historical_date"""
partition_cols = ["historical_year"]
#it works with low amount of data but to check if the size increases.
save_new_data_as_delta(my_dt,name_folder,predicate= predicate, partition_cols=partition_cols, layer = 'Gold', source= 'open-meteo-historical-daily', author ='Augustin')

#Verifying the data of the gold layer
my_dt = DeltaTable(name_folder).to_pandas()
my_dt.head()
# Out:
#         city historical_date historical_year historical_month historical_day  \
# 0  Barcelona      2013-01-28            2013               01            Mon
# 1  Barcelona      2013-01-27            2013               01            Sun
# 2  Barcelona      2013-01-17            2013               01            Thu
# 3  Barcelona      2013-02-04            2013               02            Mon
# 4  Barcelona      2013-02-25            2013               02            Mon
#
#    longitude  latitude  wind_direction_10m_dominant_deg  \
# 0    2.15899  41.38879                       300.627197
# 1    2.15899  41.38879                       282.633362
# 2    2.15899  41.38879                       116.564987
# 3    2.15899  41.38879                       301.835205
# 4    2.15899  41.38879                        49.236420
#
#    precipitation_hours_h  precipitation_sum  ...  daylight_duration_minutes  \
# 0                    5.0                2.8  ...                 596.161682
# 1                    2.0                0.8  ...                 594.073914
# 2                    4.0                0.5  ...                 574.950378
# 3                    0.0                0.0  ...                 611.725891
# 4                    0.0                0.0  ...                 665.394775
#
#    daylight_duration_hours  warm_enough  too_cold  sufficient_sunshine  \
# 0                 9.936028        False      True                 True
# 1                 9.901232        False      True                 True
# 2                 9.582506        False      True                 True
# 3                10.195432        False      True                 True
# 4                11.089913        False      True                 True
#
#    elevation_m       timezone  population  country                 description
# 0         15.0  Europe/Madrid     1621537    Spain     Drizzle dense intensity
# 1         15.0  Europe/Madrid     1621537    Spain  Drizzle moderate intensity
# 2         15.0  Europe/Madrid     1621537    Spain     Drizzle light intensity
# 3         15.0  Europe/Madrid     1621537    Spain               Partly cloudy
# 4         15.0  Europe/Madrid     1621537    Spain                    Overcast
#
# [5 rows x 36 columns]

# %% [markdown]
# ### 📈 3.2 Apply Aggregations & Comparative Analysis
#
# In this section, we will apply aggregation and comparative logic to the cleaned weather datasets, in order to extract **meaningful insights** and **business-level metrics**.
#
# 📊 **Available Datasets:**
# - `current_weather`
# - `forecast_daily_weather`
# - `forecast_hourly_weather`
# - `historical_weather`
# - `geolocation`
# - `weathercode`
#
#
# ##### 🧮 Step 1 — Compute Aggregations on Historical Data
#
# We will analyze **historical weather patterns** by computing the following:
# - **Global averages per city** (across the whole dataset);
# - **Monthly averages per city** — to observe seasonal variations;
# - **Yearly averages per city** — to analyze long-term climate trends;
# - **Global monthly and yearly averages** — useful for high-level comparisons, to analyze long-term climate trends across a cluster of cities.
#
# These aggregations will help in detecting **climatic trends**, **temperature shifts**, or **anomalies** over time.
#
#
#
# ##### 🔍 Step 2 — Forecast vs Historical Comparison : for future implementation
#
# We will assess the **forecast accuracy** by comparing forecasted data with historical records. Specifically:
# - For **daily forecasts**, compare each metric with historical daily averages.
# - For **hourly forecasts**, compare with historical hourly patterns.
#
# We will compute a **forecast accuracy score**, defined as a **percentage difference** between forecasted and actual historical values.
#
# This enables:
# - **Quantitative evaluation** of forecast reliability
# - **City-level forecast performance analysis**
#
#
#
# ##### 🧠 Step 3 — Additional Exploratory Metrics (Optional) :  for future implementation
#
# - Correlation analysis between **latitude, longitude, and elevation** with temperature and precipitation
# - Identify **outliers** or **unexpected weather behavior** in specific regions

# %% [markdown]
# ##### 🧮 3.2.1. Means per city per month

# %%
name_folder = 'Data/Gold/OpenMeteo/Historical/Daily'
my_dt = DeltaTable(name_folder).to_pandas()
groupby = ['city','historical_year', 'historical_month']
agg_columns = {'wind_direction_10m_dominant_deg':['min','max','mean']
               ,'precipitation_hours_h':'mean'
               ,'precipitation_sum':'mean'
               ,'apparent_temperature_max_C':'mean'
               ,'daylight_duration_seconds':'mean'
               ,'wind_gusts_10m_max_kmh':'mean'
               ,'snowfall_sum_cm':'mean'
               , 'temperature_2m_min_C':'mean'
               ,'et0_fao_evapotranspiration_mm':'mean'
               ,'wind_speed_10m_max_kmh':'mean'
               ,'showers_sum_mm':'mean'
               ,'temperature_2m_max_C':'mean'
               ,'shortwave_radiation_sum_MJm2':'mean'
               ,'rain_sum_mm':'mean'
               ,'sunshine_duration_seconds':'mean'
               ,'apparent_temperature_min_C':'mean'
               ,'sunshine_duration_minutes':'mean'
               ,'sunshine_duration_hours':'mean'
               ,'daylight_duration_minutes':'mean'
               ,'daylight_duration_hours':'mean'
               ,'weather_code':lambda x: x.mode().iloc[0] }

my_dt =aggregate_dataframe(my_dt, groupby, agg_columns)
my_dt.head()
# Out:
#         city historical_year historical_month  \
# 0  Barcelona            2010               01
# 1  Barcelona            2010               02
# 2  Barcelona            2010               03
# 3  Barcelona            2010               04
# 4  Barcelona            2010               05
#
#    wind_direction_10m_dominant_deg_MIN  wind_direction_10m_dominant_deg_MAX  \
# 0                            21.209312                           340.920624
# 1                             6.916732                           314.799225
# 2                            22.299452                           358.054688
# 3                            27.315474                           275.102081
# 4                            34.653992                           281.527130
#
#    wind_direction_10m_dominant_deg_MEAN  precipitation_hours_h_MEAN  \
# 0                            181.725616                    4.903226
# 1                            183.862930                    4.142857
# 2                            188.971069                    3.258065
# 3                            183.652283                    1.566667
# 4                            170.053055                    5.193548
#
#    precipitation_sum_MEAN  apparent_temperature_max_C_MEAN  \
# 0                2.377419                         8.945212
# 1                2.892857                         9.794568
# 2                2.564516                        12.013682
# 3                0.523333                        17.238020
# 4                3.551613                        19.998240
#
#    daylight_duration_seconds_MEAN  ...  temperature_2m_max_C_MEAN  \
# 0                    34491.246094  ...                  11.314355
# 1                    38254.699219  ...                  12.696786
# 2                    43027.148438  ...                  14.230483
# 3                    48013.386719  ...                  17.670000
# 4                    52247.675781  ...                  19.461128
#
#    shortwave_radiation_sum_MJm2_MEAN  rain_sum_mm_MEAN  \
# 0                           6.125484          2.254839
# 1                           9.768214          2.867857
# 2                          15.243226          1.977419
# 3                          19.000000          0.523333
# 4                          21.741613          3.551613
#
#    sunshine_duration_seconds_MEAN  apparent_temperature_min_C_MEAN  \
# 0                    19725.250000                         3.090729
# 1                    25891.765625                         2.730789
# 2                    33314.097656                         4.588932
# 3                    37735.097656                         9.062257
# 4                    43421.300781                        12.292632
#
#    sunshine_duration_minutes_MEAN  sunshine_duration_hours_MEAN  \
# 0                      328.754150                      5.479236
# 1                      431.529388                      7.192157
# 2                      555.234985                      9.253916
# 3                      628.918213                     10.481970
# 4                      723.688354                     12.061473
#
#    daylight_duration_minutes_MEAN  daylight_duration_hours_MEAN  \
# 0                      574.854065                      9.580901
# 1                      637.578430                     10.626306
# 2                      717.119141                     11.951986
# 3                      800.223083                     13.337051
# 4                      870.794678                     14.513245
#
#    weather_code_<LAMBDA>
# 0                      3
# 1                      3
# 2                      3
# 3                      3
# 4                     51
#
# [5 rows x 26 columns]

# %%
#STORING THE DATA
name_folder = 'Data/Gold/OpenMeteo/Historical/Calculations/PerCityPerMonth'
save_data_as_delta(my_dt, name_folder, mode="overwrite", layer='Gold',source='open-meteo-historical-daily', author='Augustin')

#Verifying the data of the gold layer
my_dt = DeltaTable(name_folder).to_pandas()
my_dt.head()
# Out:
#         city historical_year historical_month  \
# 0  Barcelona            2010               01
# 1  Barcelona            2010               02
# 2  Barcelona            2010               03
# 3  Barcelona            2010               04
# 4  Barcelona            2010               05
#
#    wind_direction_10m_dominant_deg_MIN  wind_direction_10m_dominant_deg_MAX  \
# 0                            21.209312                           340.920624
# 1                             6.916732                           314.799225
# 2                            22.299452                           358.054688
# 3                            27.315474                           275.102081
# 4                            34.653992                           281.527130
#
#    wind_direction_10m_dominant_deg_MEAN  precipitation_hours_h_MEAN  \
# 0                            181.725616                    4.903226
# 1                            183.862930                    4.142857
# 2                            188.971069                    3.258065
# 3                            183.652283                    1.566667
# 4                            170.053055                    5.193548
#
#    precipitation_sum_MEAN  apparent_temperature_max_C_MEAN  \
# 0                2.377419                         8.945212
# 1                2.892857                         9.794568
# 2                2.564516                        12.013682
# 3                0.523333                        17.238020
# 4                3.551613                        19.998240
#
#    daylight_duration_seconds_MEAN  ...  temperature_2m_max_C_MEAN  \
# 0                    34491.246094  ...                  11.314355
# 1                    38254.699219  ...                  12.696786
# 2                    43027.148438  ...                  14.230483
# 3                    48013.386719  ...                  17.670000
# 4                    52247.675781  ...                  19.461128
#
#    shortwave_radiation_sum_MJm2_MEAN  rain_sum_mm_MEAN  \
# 0                           6.125484          2.254839
# 1                           9.768214          2.867857
# 2                          15.243226          1.977419
# 3                          19.000000          0.523333
# 4                          21.741613          3.551613
#
#    sunshine_duration_seconds_MEAN  apparent_temperature_min_C_MEAN  \
# 0                    19725.250000                         3.090729
# 1                    25891.765625                         2.730789
# 2                    33314.097656                         4.588932
# 3                    37735.097656                         9.062257
# 4                    43421.300781                        12.292632
#
#    sunshine_duration_minutes_MEAN  sunshine_duration_hours_MEAN  \
# 0                      328.754150                      5.479236
# 1                      431.529388                      7.192157
# 2                      555.234985                      9.253916
# 3                      628.918213                     10.481970
# 4                      723.688354                     12.061473
#
#    daylight_duration_minutes_MEAN  daylight_duration_hours_MEAN  \
# 0                      574.854065                      9.580901
# 1                      637.578430                     10.626306
# 2                      717.119141                     11.951986
# 3                      800.223083                     13.337051
# 4                      870.794678                     14.513245
#
#    weather_code_<LAMBDA>
# 0                      3
# 1                      3
# 2                      3
# 3                      3
# 4                     51
#
# [5 rows x 26 columns]

# %% [markdown]
# ##### 🧮 3.2.2. Means per city per year

# %%
name_folder = 'Data/Gold/OpenMeteo/Historical/Daily'
my_dt = DeltaTable(name_folder).to_pandas()
groupby = ['city','historical_year']
agg_columns = {'wind_direction_10m_dominant_deg':['min','max','mean']
               ,'precipitation_hours_h':'mean'
               ,'precipitation_sum':'mean'
               ,'apparent_temperature_max_C':'mean'
               ,'daylight_duration_seconds':'mean'
               ,'wind_gusts_10m_max_kmh':'mean'
               ,'snowfall_sum_cm':'mean'
               , 'temperature_2m_min_C':'mean'
               ,'et0_fao_evapotranspiration_mm':'mean'
               ,'wind_speed_10m_max_kmh':'mean'
               ,'showers_sum_mm':'mean'
               ,'temperature_2m_max_C':'mean'
               ,'shortwave_radiation_sum_MJm2':'mean'
               ,'rain_sum_mm':'mean'
               ,'sunshine_duration_seconds':'mean'
               ,'apparent_temperature_min_C':'mean'
               ,'sunshine_duration_minutes':'mean'
               ,'sunshine_duration_hours':'mean'
               ,'daylight_duration_minutes':'mean'
               ,'daylight_duration_hours':'mean'
               ,'weather_code':lambda x: x.mode().iloc[0] }

my_dt =aggregate_dataframe(my_dt, groupby, agg_columns)
my_dt.head(2)
# Out:
#         city historical_year  wind_direction_10m_dominant_deg_MIN  \
# 0  Barcelona            2010                             3.813969
# 1  Barcelona            2011                             2.076218
#
#    wind_direction_10m_dominant_deg_MAX  wind_direction_10m_dominant_deg_MEAN  \
# 0                           358.054688                            189.707962
# 1                           359.999939                            181.439728
#
#    precipitation_hours_h_MEAN  precipitation_sum_MEAN  \
# 0                    3.397260                1.956438
# 1                    2.654794                1.599452
#
#    apparent_temperature_max_C_MEAN  daylight_duration_seconds_MEAN  \
# 0                        18.843021                    43955.074219
# 1                        20.602261                    43955.238281
#
#    wind_gusts_10m_max_kmh_MEAN  ...  temperature_2m_max_C_MEAN  \
# 0                    31.305204  ...                  18.988974
# 1                    29.398684  ...                  20.298698
#
#    shortwave_radiation_sum_MJm2_MEAN  rain_sum_mm_MEAN  \
# 0                          15.075836          1.893151
# 1                          15.863863          1.599452
#
#    sunshine_duration_seconds_MEAN  apparent_temperature_min_C_MEAN  \
# 0                    34342.546875                        11.756217
# 1                    36369.554688                        13.244725
#
#    sunshine_duration_minutes_MEAN  sunshine_duration_hours_MEAN  \
# 0                      572.375793                      9.539597
# 1                      606.159302                     10.102654
#
#    daylight_duration_minutes_MEAN  daylight_duration_hours_MEAN  \
# 0                      732.584595                     12.209743
# 1                      732.587341                     12.209788
#
#    weather_code_<LAMBDA>
# 0                      3
# 1                      3
#
# [2 rows x 25 columns]

# %%
#STORING THE DATA
name_folder = 'Data/Gold/OpenMeteo/Historical/Calculations/PerCityPerYear'
save_data_as_delta(my_dt, name_folder, mode="overwrite", layer='Gold',source='open-meteo-historical-daily', author='Augustin')

#Verifying the data of the gold layer
my_dt = DeltaTable(name_folder).to_pandas()
my_dt.head()
# Out:
#         city historical_year  wind_direction_10m_dominant_deg_MIN  \
# 0  Barcelona            2010                             3.813969
# 1  Barcelona            2011                             2.076218
# 2  Barcelona            2012                             0.473433
# 3  Barcelona            2013                             0.000046
# 4  Barcelona            2016                             0.364887
#
#    wind_direction_10m_dominant_deg_MAX  wind_direction_10m_dominant_deg_MEAN  \
# 0                           358.054688                            189.707962
# 1                           359.999939                            181.439728
# 2                           355.962402                            190.508514
# 3                           359.610168                            197.353226
# 4                           359.692749                            183.213120
#
#    precipitation_hours_h_MEAN  precipitation_sum_MEAN  \
# 0                    3.397260                1.956438
# 1                    2.654794                1.599452
# 2                    2.073771                1.245082
# 3                    2.794521                1.670411
# 4                    2.527322                1.457650
#
#    apparent_temperature_max_C_MEAN  daylight_duration_seconds_MEAN  \
# 0                        18.843021                    43955.074219
# 1                        20.602261                    43955.238281
# 2                        20.143944                    43925.964844
# 3                        19.750835                    43955.203125
# 4                        20.659861                    43926.230469
#
#    wind_gusts_10m_max_kmh_MEAN  ...  temperature_2m_max_C_MEAN  \
# 0                    31.305204  ...                  18.988974
# 1                    29.398684  ...                  20.298698
# 2                    30.775082  ...                  20.235710
# 3                    31.835836  ...                  19.867056
# 4                    30.892130  ...                  20.535559
#
#    shortwave_radiation_sum_MJm2_MEAN  rain_sum_mm_MEAN  \
# 0                          15.075836          1.893151
# 1                          15.863863          1.599452
# 2                          16.407732          1.238525
# 3                          15.612520          1.663288
# 4                          15.748087          1.457650
#
#    sunshine_duration_seconds_MEAN  apparent_temperature_min_C_MEAN  \
# 0                    34342.546875                        11.756217
# 1                    36369.554688                        13.244725
# 2                    36560.914062                        12.451295
# 3                    35721.398438                        12.273068
# 4                    36032.515625                        13.077597
#
#    sunshine_duration_minutes_MEAN  sunshine_duration_hours_MEAN  \
# 0                      572.375793                      9.539597
# 1                      606.159302                     10.102654
# 2                      609.348511                     10.155809
# 3                      595.356689                      9.922611
# 4                      600.541992                     10.009032
#
#    daylight_duration_minutes_MEAN  daylight_duration_hours_MEAN  \
# 0                      732.584595                     12.209743
# 1                      732.587341                     12.209788
# 2                      732.099487                     12.201657
# 3                      732.586731                     12.209779
# 4                      732.103821                     12.201731
#
#    weather_code_<LAMBDA>
# 0                      3
# 1                      3
# 2                      3
# 3                      3
# 4                      3
#
# [5 rows x 25 columns]

# %% [markdown]
# ##### 🧮 3.2.3. Means overall countries per month

# %%
name_folder = 'Data/Gold/OpenMeteo/Historical/Daily'
my_dt = DeltaTable(name_folder).to_pandas()
groupby = ['historical_year','historical_month']
agg_columns = {'wind_direction_10m_dominant_deg':['min','max','mean']
               ,'precipitation_hours_h':'mean'
               ,'precipitation_sum':'mean'
               ,'apparent_temperature_max_C':'mean'
               ,'daylight_duration_seconds':'mean'
               ,'wind_gusts_10m_max_kmh':'mean'
               ,'snowfall_sum_cm':'mean'
               , 'temperature_2m_min_C':'mean'
               ,'et0_fao_evapotranspiration_mm':'mean'
               ,'wind_speed_10m_max_kmh':'mean'
               ,'showers_sum_mm':'mean'
               ,'temperature_2m_max_C':'mean'
               ,'shortwave_radiation_sum_MJm2':'mean'
               ,'rain_sum_mm':'mean'
               ,'sunshine_duration_seconds':'mean'
               ,'apparent_temperature_min_C':'mean'
               ,'sunshine_duration_minutes':'mean'
               ,'sunshine_duration_hours':'mean'
               ,'daylight_duration_minutes':'mean'
               ,'daylight_duration_hours':'mean'
               ,'weather_code':lambda x: x.mode().iloc[0] }

my_dt =aggregate_dataframe(my_dt, groupby, agg_columns)
my_dt.head(5)
# Out:
#   historical_year historical_month  wind_direction_10m_dominant_deg_MIN  \
# 0            2010               01                             1.432091
# 1            2010               02                             1.537713
# 2            2010               03                             1.778750
# 3            2010               04                             0.422862
# 4            2010               05                             0.897164
#
#    wind_direction_10m_dominant_deg_MAX  wind_direction_10m_dominant_deg_MEAN  \
# 0                           358.986053                            189.476181
# 1                           359.610809                            189.849503
# 2                           359.714386                            182.350708
# 3                           357.929993                            186.750519
# 4                           359.123108                            191.353516
#
#    precipitation_hours_h_MEAN  precipitation_sum_MEAN  \
# 0                    3.372760                2.168459
# 1                    4.142857                3.007738
# 2                    3.281362                2.878495
# 3                    2.833333                1.747037
# 4                    2.573477                1.681004
#
#    apparent_temperature_max_C_MEAN  daylight_duration_seconds_MEAN  \
# 0                        11.686591                    38814.847656
# 1                        12.858019                    40825.683594
# 2                        16.092392                    43342.796875
# 3                        18.965096                    45982.906250
# 4                        20.704971                    48272.687500
#
#    wind_gusts_10m_max_kmh_MEAN  ...  temperature_2m_max_C_MEAN  \
# 0                    35.526451  ...                  13.011835
# 1                    38.695000  ...                  14.246036
# 2                    38.107098  ...                  17.288538
# 3                    35.669998  ...                  19.701887
# 4                    35.599354  ...                  21.188807
#
#    shortwave_radiation_sum_MJm2_MEAN  rain_sum_mm_MEAN  \
# 0                          12.511756          1.901434
# 1                          13.815198          2.449008
# 2                          16.216846          2.735305
# 3                          18.593388          1.715926
# 4                          18.945932          1.681004
#
#    sunshine_duration_seconds_MEAN  apparent_temperature_min_C_MEAN  \
# 0                    26589.986328                         3.964203
# 1                    27422.531250                         5.027880
# 2                    31881.773438                         7.396659
# 3                    35620.183594                         9.272553
# 4                    36703.542969                        11.385653
#
#    sunshine_duration_minutes_MEAN  sunshine_duration_hours_MEAN  \
# 0                      443.166443                      7.386107
# 1                      457.042206                      7.617370
# 2                      531.362915                      8.856049
# 3                      593.669739                      9.894496
# 4                      611.725708                     10.195428
#
#    daylight_duration_minutes_MEAN  daylight_duration_hours_MEAN  \
# 0                      646.914124                     10.781903
# 1                      680.428101                     11.340467
# 2                      722.379944                     12.039666
# 3                      766.381775                     12.773029
# 4                      804.544800                     13.409081
#
#    weather_code_<LAMBDA>
# 0                      3
# 1                      3
# 2                      3
# 3                      3
# 4                      3
#
# [5 rows x 25 columns]

# %%
#STORING THE DATA
name_folder = 'Data/Gold/OpenMeteo/Historical/Calculations/PerMonth'
save_data_as_delta(my_dt, name_folder, mode="overwrite", layer='Gold',source='open-meteo-historical-daily', author='Augustin')

#Verifying the data of the gold layer
my_dt = DeltaTable(name_folder).to_pandas()
my_dt.head()
# Out:
#   historical_year historical_month  wind_direction_10m_dominant_deg_MIN  \
# 0            2010               01                             1.432091
# 1            2010               02                             1.537713
# 2            2010               03                             1.778750
# 3            2010               04                             0.422862
# 4            2010               05                             0.897164
#
#    wind_direction_10m_dominant_deg_MAX  wind_direction_10m_dominant_deg_MEAN  \
# 0                           358.986053                            189.476181
# 1                           359.610809                            189.849503
# 2                           359.714386                            182.350708
# 3                           357.929993                            186.750519
# 4                           359.123108                            191.353516
#
#    precipitation_hours_h_MEAN  precipitation_sum_MEAN  \
# 0                    3.372760                2.168459
# 1                    4.142857                3.007738
# 2                    3.281362                2.878495
# 3                    2.833333                1.747037
# 4                    2.573477                1.681004
#
#    apparent_temperature_max_C_MEAN  daylight_duration_seconds_MEAN  \
# 0                        11.686591                    38814.847656
# 1                        12.858019                    40825.683594
# 2                        16.092392                    43342.796875
# 3                        18.965096                    45982.906250
# 4                        20.704971                    48272.687500
#
#    wind_gusts_10m_max_kmh_MEAN  ...  temperature_2m_max_C_MEAN  \
# 0                    35.526451  ...                  13.011835
# 1                    38.695000  ...                  14.246036
# 2                    38.107098  ...                  17.288538
# 3                    35.669998  ...                  19.701887
# 4                    35.599354  ...                  21.188807
#
#    shortwave_radiation_sum_MJm2_MEAN  rain_sum_mm_MEAN  \
# 0                          12.511756          1.901434
# 1                          13.815198          2.449008
# 2                          16.216846          2.735305
# 3                          18.593388          1.715926
# 4                          18.945932          1.681004
#
#    sunshine_duration_seconds_MEAN  apparent_temperature_min_C_MEAN  \
# 0                    26589.986328                         3.964203
# 1                    27422.531250                         5.027880
# 2                    31881.773438                         7.396659
# 3                    35620.183594                         9.272553
# 4                    36703.542969                        11.385653
#
#    sunshine_duration_minutes_MEAN  sunshine_duration_hours_MEAN  \
# 0                      443.166443                      7.386107
# 1                      457.042206                      7.617370
# 2                      531.362915                      8.856049
# 3                      593.669739                      9.894496
# 4                      611.725708                     10.195428
#
#    daylight_duration_minutes_MEAN  daylight_duration_hours_MEAN  \
# 0                      646.914124                     10.781903
# 1                      680.428101                     11.340467
# 2                      722.379944                     12.039666
# 3                      766.381775                     12.773029
# 4                      804.544800                     13.409081
#
#    weather_code_<LAMBDA>
# 0                      3
# 1                      3
# 2                      3
# 3                      3
# 4                      3
#
# [5 rows x 25 columns]

# %% [markdown]
# ##### 🧮 3.2.4. Means overall countries per year

# %%
name_folder = 'Data/Gold/OpenMeteo/Historical/Daily'
my_dt = DeltaTable(name_folder).to_pandas()
groupby = ['historical_year']
agg_columns = {'wind_direction_10m_dominant_deg':['min','max','mean']
               ,'precipitation_hours_h':'mean'
               ,'precipitation_sum':'mean'
               ,'apparent_temperature_max_C':'mean'
               ,'daylight_duration_seconds':'mean'
               ,'wind_gusts_10m_max_kmh':'mean'
               ,'snowfall_sum_cm':'mean'
               , 'temperature_2m_min_C':'mean'
               ,'et0_fao_evapotranspiration_mm':'mean'
               ,'wind_speed_10m_max_kmh':'mean'
               ,'showers_sum_mm':'mean'
               ,'temperature_2m_max_C':'mean'
               ,'shortwave_radiation_sum_MJm2':'mean'
               ,'rain_sum_mm':'mean'
               ,'sunshine_duration_seconds':'mean'
               ,'apparent_temperature_min_C':'mean'
               ,'sunshine_duration_minutes':'mean'
               ,'sunshine_duration_hours':'mean'
               ,'daylight_duration_minutes':'mean'
               ,'daylight_duration_hours':'mean'
               ,'weather_code':lambda x: x.mode().iloc[0] }

my_dt =aggregate_dataframe(my_dt, groupby, agg_columns)
my_dt.head(10)
# Out:
#   historical_year  wind_direction_10m_dominant_deg_MIN  \
# 0            2010                             0.132633
# 1            2011                             0.000005
# 2            2012                             0.123495
# 3            2013                             0.000046
# 4            2016                             0.000046
# 5            2018                             0.000005
# 6            2019                             0.063526
# 7            2020                             0.189092
# 8            2021                             0.103045
# 9            2022                             0.000128
#
#    wind_direction_10m_dominant_deg_MAX  wind_direction_10m_dominant_deg_MEAN  \
# 0                           359.999969                            191.827621
# 1                           359.999969                            184.626678
# 2                           359.999969                            190.983566
# 3                           359.999969                            188.623444
# 4                           359.999969                            190.417831
# 5                           359.999969                            189.520172
# 6                           359.999969                            196.506866
# 7                           359.968353                            192.767044
# 8                           360.000000                            192.347672
# 9                           359.999969                            190.866287
#
#    precipitation_hours_h_MEAN  precipitation_sum_MEAN  \
# 0                    3.148706                2.255997
# 1                    3.059513                2.208326
# 2                    3.036582                2.082210
# 3                    3.086806                2.114376
# 4                    3.020188                2.086202
# 5                    4.282192                2.848043
# 6                    4.147749                2.732407
# 7                    3.949649                2.543228
# 8                    4.163405                2.684755
# 9                    3.618004                2.577182
#
#    apparent_temperature_max_C_MEAN  daylight_duration_seconds_MEAN  \
# 0                        18.372244                    43852.160156
# 1                        18.867092                    43852.246094
# 2                        19.169992                    43836.628906
# 3                        19.041803                    43842.222656
# 4                        19.230024                    43836.765625
# 5                        17.389984                    43887.613281
# 6                        17.226034                    43887.828125
# 7                        17.491987                    43870.316406
# 8                        17.118025                    43887.722656
# 9                        17.658636                    43887.480469
#
#    wind_gusts_10m_max_kmh_MEAN  snowfall_sum_cm_MEAN  ...  \
# 0                    36.517315              0.096317  ...
# 1                    36.488110              0.081592  ...
# 2                    36.722294              0.067652  ...
# 3                    36.921932              0.107094  ...
# 4                    36.958687              0.077066  ...
# 5                    39.933651              0.096603  ...
# 6                    41.119465              0.096096  ...
# 7                    41.418690              0.065273  ...
# 8                    39.702644              0.087822  ...
# 9                    38.859848              0.081027  ...
#
#    temperature_2m_max_C_MEAN  shortwave_radiation_sum_MJm2_MEAN  \
# 0                  19.006775                          15.845911
# 1                  19.352322                          15.849396
# 2                  19.657406                          15.964025
# 3                  19.559967                          16.047319
# 4                  19.638399                          15.845064
# 5                  18.335117                          14.799181
# 6                  18.368162                          15.100665
# 7                  18.727514                          15.209746
# 8                  18.251059                          15.152159
# 9                  18.749727                          15.666607
#
#    rain_sum_mm_MEAN  sunshine_duration_seconds_MEAN  \
# 0          2.129589                    32150.509766
# 1          2.098387                    32184.056641
# 2          1.990027                    32479.445312
# 3          1.971190                    32162.359375
# 4          1.982301                    32314.154297
# 5          2.710391                    30154.843750
# 6          2.595499                    30763.587891
# 7          2.450039                    31247.123047
# 8          2.559472                    30904.958984
# 9          2.461683                    31362.736328
#
#    apparent_temperature_min_C_MEAN  sunshine_duration_minutes_MEAN  \
# 0                         9.976358                      535.841797
# 1                        10.323406                      536.400940
# 2                        10.669188                      541.324097
# 3                        10.375408                      536.039307
# 4                        10.793228                      538.569275
# 5                         8.478782                      502.580719
# 6                         8.119406                      512.726440
# 7                         8.538176                      520.785400
# 8                         8.357899                      515.082642
# 9                         8.256819                      522.712280
#
#    sunshine_duration_hours_MEAN  daylight_duration_minutes_MEAN  \
# 0                      8.930697                      730.869324
# 1                      8.940016                      730.870728
# 2                      9.022068                      730.610474
# 3                      8.933990                      730.703674
# 4                      8.976154                      730.612793
# 5                      8.376346                      731.460205
# 6                      8.545441                      731.463806
# 7                      8.679756                      731.171936
# 8                      8.584710                      731.462036
# 9                      8.711872                      731.457947
#
#    daylight_duration_hours_MEAN  weather_code_<LAMBDA>
# 0                     12.181156                      3
# 1                     12.181179                      3
# 2                     12.176842                      3
# 3                     12.178395                      3
# 4                     12.176879                      3
# 5                     12.191004                      3
# 6                     12.191063                      3
# 7                     12.186198                      3
# 8                     12.191034                      3
# 9                     12.190967                      3
#
# [10 rows x 24 columns]

# %%
#STORING THE DATA
name_folder = 'Data/Gold/OpenMeteo/Historical/Calculations/PerYear'
save_data_as_delta(my_dt, name_folder, mode="overwrite", layer='Gold',source='open-meteo-historical-daily', author='Augustin')

#Verifying the data of the gold layer
my_dt = DeltaTable(name_folder).to_pandas()
my_dt.head(15)
# Out:
#    historical_year  wind_direction_10m_dominant_deg_MIN  \
# 0             2010                             0.132633
# 1             2011                             0.000005
# 2             2012                             0.123495
# 3             2013                             0.000046
# 4             2016                             0.000046
# 5             2018                             0.000005
# 6             2019                             0.063526
# 7             2020                             0.189092
# 8             2021                             0.103045
# 9             2022                             0.000128
# 10            2023                             0.030276
# 11            2024                             0.075301
#
#     wind_direction_10m_dominant_deg_MAX  wind_direction_10m_dominant_deg_MEAN  \
# 0                            359.999969                            191.827621
# 1                            359.999969                            184.626678
# 2                            359.999969                            190.983566
# 3                            359.999969                            188.623444
# 4                            359.999969                            190.417831
# 5                            359.999969                            189.520172
# 6                            359.999969                            196.506866
# 7                            359.968353                            192.767044
# 8                            360.000000                            192.347672
# 9                            359.999969                            190.866287
# 10                           359.999939                            195.886749
# 11                           359.855286                            195.073761
#
#     precipitation_hours_h_MEAN  precipitation_sum_MEAN  \
# 0                     3.148706                2.255997
# 1                     3.059513                2.208326
# 2                     3.036582                2.082210
# 3                     3.086806                2.114376
# 4                     3.020188                2.086202
# 5                     4.282192                2.848043
# 6                     4.147749                2.732407
# 7                     3.949649                2.543228
# 8                     4.163405                2.684755
# 9                     3.618004                2.577182
# 10                    3.827397                2.683464
# 11                    3.870219                2.811163
#
#     apparent_temperature_max_C_MEAN  daylight_duration_seconds_MEAN  \
# 0                         18.372244                    43852.160156
# 1                         18.867092                    43852.246094
# 2                         19.169992                    43836.628906
# 3                         19.041803                    43842.222656
# 4                         19.230024                    43836.765625
# 5                         17.389984                    43887.613281
# 6                         17.226034                    43887.828125
# 7                         17.491987                    43870.316406
# 8                         17.118025                    43887.722656
# 9                         17.658636                    43887.480469
# 10                        18.073561                    43887.464844
# 11                        18.355694                    43870.109375
#
#     wind_gusts_10m_max_kmh_MEAN  snowfall_sum_cm_MEAN  ...  \
# 0                     36.517315              0.096317  ...
# 1                     36.488110              0.081592  ...
# 2                     36.722294              0.067652  ...
# 3                     36.921932              0.107094  ...
# 4                     36.958687              0.077066  ...
# 5                     39.933651              0.096603  ...
# 6                     41.119465              0.096096  ...
# 7                     41.418690              0.065273  ...
# 8                     39.702644              0.087822  ...
# 9                     38.859848              0.081027  ...
# 10                    39.200195              0.079658  ...
# 11                    39.216885              0.063279  ...
#
#     temperature_2m_max_C_MEAN  shortwave_radiation_sum_MJm2_MEAN  \
# 0                   19.006775                          15.845911
# 1                   19.352322                          15.849396
# 2                   19.657406                          15.964025
# 3                   19.559967                          16.047319
# 4                   19.638399                          15.845064
# 5                   18.335117                          14.799181
# 6                   18.368162                          15.100665
# 7                   18.727514                          15.209746
# 8                   18.251059                          15.152159
# 9                   18.749727                          15.666607
# 10                  19.140255                          15.535904
# 11                  19.319328                          15.448959
#
#     rain_sum_mm_MEAN  sunshine_duration_seconds_MEAN  \
# 0           2.129589                    32150.509766
# 1           2.098387                    32184.056641
# 2           1.990027                    32479.445312
# 3           1.971190                    32162.359375
# 4           1.982301                    32314.154297
# 5           2.710391                    30154.843750
# 6           2.595499                    30763.587891
# 7           2.450039                    31247.123047
# 8           2.559472                    30904.958984
# 9           2.461683                    31362.736328
# 10          2.569882                    30713.437500
# 11          2.720999                    30544.083984
#
#     apparent_temperature_min_C_MEAN  sunshine_duration_minutes_MEAN  \
# 0                          9.976358                      535.841797
# 1                         10.323406                      536.400940
# 2                         10.669188                      541.324097
# 3                         10.375408                      536.039307
# 4                         10.793228                      538.569275
# 5                          8.478782                      502.580719
# 6                          8.119406                      512.726440
# 7                          8.538176                      520.785400
# 8                          8.357899                      515.082642
# 9                          8.256819                      522.712280
# 10                         8.832999                      511.890594
# 11                         9.079659                      509.068054
#
#     sunshine_duration_hours_MEAN  daylight_duration_minutes_MEAN  \
# 0                       8.930697                      730.869324
# 1                       8.940016                      730.870728
# 2                       9.022068                      730.610474
# 3                       8.933990                      730.703674
# 4                       8.976154                      730.612793
# 5                       8.376346                      731.460205
# 6                       8.545441                      731.463806
# 7                       8.679756                      731.171936
# 8                       8.584710                      731.462036
# 9                       8.711872                      731.457947
# 10                      8.531510                      731.457703
# 11                      8.484468                      731.168518
#
#     daylight_duration_hours_MEAN  weather_code_<LAMBDA>
# 0                      12.181156                      3
# 1                      12.181179                      3
# 2                      12.176842                      3
# 3                      12.178395                      3
# 4                      12.176879                      3
# 5                      12.191004                      3
# 6                      12.191063                      3
# 7                      12.186198                      3
# 8                      12.191034                      3
# 9                      12.190967                      3
# 10                     12.190962                      3
# 11                     12.186142                      3
#
# [12 rows x 24 columns]

# %% [markdown]
# ##### 🧮 3.2.5. Means forecast per city per day

# %%
name_folder = 'Data/Gold/OpenMeteo/Forecast/Hourly'
my_dt = DeltaTable(name_folder).to_pandas()

groupby = ['requested_date', 'city', 'forecast_date']
agg_columns = {'temperature_2m_C': 'mean',
    'relative_humidity_2m_inPercent': 'mean',
    'apparent_temperature_C': 'mean',
    'wind_speed_10m_kmh': 'mean',
    'precipitation_mm': 'mean',
    'rain_mm': 'mean',
    'snowfall_cm': 'mean',
    'pressure_msl_hPa': 'mean',
    'cloud_cover_inPercent': 'mean',
    'visibility_m': 'mean',
    'soil_temperature_0cm_C': 'mean',
    'soil_moisture_0_to_1cm_m3m3': 'mean'
}
my_dt =aggregate_dataframe(my_dt, groupby, agg_columns)


my_dt.head(5)
# Out:
#   requested_date       city forecast_date  temperature_2m_C_MEAN  \
# 0     2025-04-11  Barcelona    2025-04-10              15.118917
# 1     2025-04-11  Barcelona    2025-04-11              14.221001
# 2     2025-04-11  Barcelona    2025-04-12              15.623084
# 3     2025-04-11  Barcelona    2025-04-13              15.798083
# 4     2025-04-11  Barcelona    2025-04-14              16.148085
#
#    relative_humidity_2m_inPercent_MEAN  apparent_temperature_C_MEAN  \
# 0                            83.916664                    14.993148
# 1                            83.333336                    13.796891
# 2                            76.500000                    15.278325
# 3                            83.291664                    16.019545
# 4                            81.291664                    15.894337
#
#    wind_speed_10m_kmh_MEAN  precipitation_mm_MEAN  rain_mm_MEAN  \
# 0                 7.029439               0.000000           0.0
# 1                 6.286100               0.000000           0.0
# 2                 6.146988               0.000000           0.0
# 3                 5.351457               0.016667           0.0
# 4                 7.985165               0.304167           0.0
#
#    snowfall_cm_MEAN  pressure_msl_hPa_MEAN  cloud_cover_inPercent_MEAN  \
# 0               0.0            1021.270813                   69.916664
# 1               0.0            1019.845886                   87.250000
# 2               0.0            1012.066650                   93.958336
# 3               0.0            1008.225037                   99.166664
# 4               0.0            1006.420837                   92.875000
#
#    visibility_m_MEAN  soil_temperature_0cm_C_MEAN  \
# 0       18199.166016                    17.343916
# 1       21068.333984                    16.631416
# 2       33533.332031                    17.810583
# 3       19317.500000                    17.843916
# 4       25020.833984                    17.771000
#
#    soil_moisture_0_to_1cm_m3m3_MEAN
# 0                          0.262292
# 1                          0.259292
# 2                          0.255042
# 3                          0.253750
# 4                          0.316458

# %%
#STORING THE DATA
name_folder = 'Data/Gold/OpenMeteo/Forecast/Calculations/PerCityPerDay'
save_data_as_delta(my_dt, name_folder, mode="overwrite", layer='Gold',source='open-meteo-forecast-daily', author='Augustin')

# Verifying the data of the gold layer
my_dt = DeltaTable(name_folder).to_pandas()
my_dt.head()
# Out:
#   requested_date       city forecast_date  temperature_2m_C_MEAN  \
# 0     2025-04-11  Barcelona    2025-04-10              15.118917
# 1     2025-04-11  Barcelona    2025-04-11              14.221001
# 2     2025-04-11  Barcelona    2025-04-12              15.623084
# 3     2025-04-11  Barcelona    2025-04-13              15.798083
# 4     2025-04-11  Barcelona    2025-04-14              16.148085
#
#    relative_humidity_2m_inPercent_MEAN  apparent_temperature_C_MEAN  \
# 0                            83.916664                    14.993148
# 1                            83.333336                    13.796891
# 2                            76.500000                    15.278325
# 3                            83.291664                    16.019545
# 4                            81.291664                    15.894337
#
#    wind_speed_10m_kmh_MEAN  precipitation_mm_MEAN  rain_mm_MEAN  \
# 0                 7.029439               0.000000           0.0
# 1                 6.286100               0.000000           0.0
# 2                 6.146988               0.000000           0.0
# 3                 5.351457               0.016667           0.0
# 4                 7.985165               0.304167           0.0
#
#    snowfall_cm_MEAN  pressure_msl_hPa_MEAN  cloud_cover_inPercent_MEAN  \
# 0               0.0            1021.270813                   69.916664
# 1               0.0            1019.845886                   87.250000
# 2               0.0            1012.066650                   93.958336
# 3               0.0            1008.225037                   99.166664
# 4               0.0            1006.420837                   92.875000
#
#    visibility_m_MEAN  soil_temperature_0cm_C_MEAN  \
# 0       18199.166016                    17.343916
# 1       21068.333984                    16.631416
# 2       33533.332031                    17.810583
# 3       19317.500000                    17.843916
# 4       25020.833984                    17.771000
#
#    soil_moisture_0_to_1cm_m3m3_MEAN
# 0                          0.262292
# 1                          0.259292
# 2                          0.255042
# 3                          0.253750
# 4                          0.316458

# %% [markdown]
# ##### 🧮 3.2.6. Means forecast per city

# %%
name_folder = 'Data/Gold/OpenMeteo/Forecast/Hourly'
my_dt = DeltaTable(name_folder).to_pandas()
days_of_forecast =len(my_dt['forecast_date'].unique())


groupby = ['requested_date', 'city']
agg_columns = {'temperature_2m_C': 'mean',
    'relative_humidity_2m_inPercent': 'mean',
    'apparent_temperature_C': 'mean',
    'wind_speed_10m_kmh': 'mean',
    'precipitation_mm': 'mean',
    'rain_mm': 'mean',
    'snowfall_cm': 'mean',
    'pressure_msl_hPa': 'mean',
    'cloud_cover_inPercent': 'mean',
    'visibility_m': 'mean',
    'soil_temperature_0cm_C': 'mean',
    'soil_moisture_0_to_1cm_m3m3': 'mean'
}

my_dt =aggregate_dataframe(my_dt, groupby, agg_columns)

#insering the nb of day of forecast
my_dt.insert(2,'nb_day_of_forecast',days_of_forecast)

my_dt.head(5)
# Out:
#   requested_date          city  nb_day_of_forecast  temperature_2m_C_MEAN  \
# 0     2025-04-11     Barcelona                   7              15.381834
# 1     2025-04-11      Brussels                   7              13.035937
# 2     2025-04-11  Buenos Aires                   7              18.727583
# 3     2025-04-11       Chicago                   7               7.930583
# 4     2025-04-11        London                   7              12.088150
#
#    relative_humidity_2m_inPercent_MEAN  apparent_temperature_C_MEAN  \
# 0                            81.666664                    15.196450
# 1                            66.016670                    10.678061
# 2                            80.050003                    19.122736
# 3                            71.675003                     4.565909
# 4                            62.408333                     9.589204
#
#    wind_speed_10m_kmh_MEAN  precipitation_mm_MEAN  rain_mm_MEAN  \
# 0                 6.559830               0.064167      0.000000
# 1                10.543744               0.025833      0.025833
# 2                 9.891475               0.022500      0.000000
# 3                13.537216               0.039167      0.031667
# 4                 8.824700               0.000000      0.000000
#
#    snowfall_cm_MEAN  pressure_msl_hPa_MEAN  cloud_cover_inPercent_MEAN  \
# 0          0.000000            1013.565796                   88.633331
# 1          0.000000            1014.971680                   53.266666
# 2          0.000000            1017.578308                   59.750000
# 3          0.000583            1016.190796                   68.541664
# 4          0.000000            1013.420837                   53.658333
#
#    visibility_m_MEAN  soil_temperature_0cm_C_MEAN  \
# 0       23427.833984                    17.480167
# 1       44215.500000                    11.285833
# 2       23709.833984                    19.090916
# 3       21355.333984                     9.665584
# 4       52578.832031                    14.158566
#
#    soil_moisture_0_to_1cm_m3m3_MEAN
# 0                          0.269367
# 1                          0.255350
# 2                          0.378008
# 3                          0.289883
# 4                          0.242367

# %%
#STORING THE DATA
name_folder = 'Data/Gold/OpenMeteo/Forecast/Calculations/PerCity'
save_data_as_delta(my_dt, name_folder, mode="overwrite", layer='Gold',source='open-meteo-forecast-daily', author='Augustin')

#Verifying the data of the gold layer
my_dt = DeltaTable(name_folder).to_pandas()
my_dt.head()
# Out:
#   requested_date          city  nb_day_of_forecast  temperature_2m_C_MEAN  \
# 0     2025-04-11     Barcelona                   7              15.381834
# 1     2025-04-11      Brussels                   7              13.035937
# 2     2025-04-11  Buenos Aires                   7              18.727583
# 3     2025-04-11       Chicago                   7               7.930583
# 4     2025-04-11        London                   7              12.088150
#
#    relative_humidity_2m_inPercent_MEAN  apparent_temperature_C_MEAN  \
# 0                            81.666664                    15.196450
# 1                            66.016670                    10.678061
# 2                            80.050003                    19.122736
# 3                            71.675003                     4.565909
# 4                            62.408333                     9.589204
#
#    wind_speed_10m_kmh_MEAN  precipitation_mm_MEAN  rain_mm_MEAN  \
# 0                 6.559830               0.064167      0.000000
# 1                10.543744               0.025833      0.025833
# 2                 9.891475               0.022500      0.000000
# 3                13.537216               0.039167      0.031667
# 4                 8.824700               0.000000      0.000000
#
#    snowfall_cm_MEAN  pressure_msl_hPa_MEAN  cloud_cover_inPercent_MEAN  \
# 0          0.000000            1013.565796                   88.633331
# 1          0.000000            1014.971680                   53.266666
# 2          0.000000            1017.578308                   59.750000
# 3          0.000583            1016.190796                   68.541664
# 4          0.000000            1013.420837                   53.658333
#
#    visibility_m_MEAN  soil_temperature_0cm_C_MEAN  \
# 0       23427.833984                    17.480167
# 1       44215.500000                    11.285833
# 2       23709.833984                    19.090916
# 3       21355.333984                     9.665584
# 4       52578.832031                    14.158566
#
#    soil_moisture_0_to_1cm_m3m3_MEAN
# 0                          0.269367
# 1                          0.255350
# 2                          0.378008
# 3                          0.289883
# 4                          0.242367

# %% [markdown]
# **📊 CHECK GOLD TABLE STATS AND COMPARING WITH SILVER: Rows, Nulls, Duplicates**

# %%
#Checking gold layer
name_folder = 'Data/_meta/metadata_table'
my_dt = DeltaTable(name_folder).to_pandas()
my_dt = my_dt[my_dt['layer']=='Gold']
my_dt.head(15)
# Out:
#                                           table_path       table_name layer  \
# 0  Data/Gold/OpenMeteo/Forecast/Calculations/PerCity          PerCity  Gold
# 1  Data/Gold/OpenMeteo/Forecast/Calculations/PerC...    PerCityPerDay  Gold
# 2  Data/Gold/OpenMeteo/Historical/Calculations/Pe...          PerYear  Gold
# 3  Data/Gold/OpenMeteo/Historical/Calculations/Pe...         PerMonth  Gold
# 4  Data/Gold/OpenMeteo/Historical/Calculations/Pe...   PerCityPerYear  Gold
# 5  Data/Gold/OpenMeteo/Historical/Calculations/Pe...  PerCityPerMonth  Gold
# 6               Data/Gold/OpenMeteo/Historical/Daily            Daily  Gold
# 7                Data/Gold/OpenMeteo/Forecast/Hourly           Hourly  Gold
# 8                 Data/Gold/OpenMeteo/Forecast/Daily            Daily  Gold
# 9                        Data/Gold/OpenMeteo/Current          Current  Gold
#
#    total_rows  rows_with_nulls  rows_duplicated  \
# 0          33                0                0
# 1         193                0                0
# 2          12                0                0
# 3         144                0                0
# 4         189                0                0
# 5        2268                0                0
# 6       69049                1                0
# 7        4632                9                0
# 8         231                4                0
# 9          19                0                0
#
#                                              columns  \
# 0  ["requested_date", "city", "nb_day_of_forecast...
# 1  ["requested_date", "city", "forecast_date", "t...
# 2  ["historical_year", "wind_direction_10m_domina...
# 3  ["historical_year", "historical_month", "wind_...
# 4  ["city", "historical_year", "wind_direction_10...
# 5  ["city", "historical_year", "historical_month"...
# 6  ["city", "historical_date", "historical_year",...
# 7  ["requested_date", "city", "forecast_date", "f...
# 8  ["requested_date", "city", "forecast_day", "we...
# 9  ["date", "time", "city", "longitude", "latitud...
#
#                                               dtypes  delta_table_size_MB  \
# 0  {"requested_date": "datetime64[us]", "city": "...                 0.08
# 1  {"requested_date": "datetime64[us]", "city": "...                 0.12
# 2  {"historical_year": "object", "wind_direction_...                 0.11
# 3  {"historical_year": "object", "historical_mont...                 0.20
# 4  {"city": "object", "historical_year": "object"...                 0.22
# 5  {"city": "object", "historical_year": "object"...                 1.42
# 6  {"city": "object", "historical_date": "datetim...                 5.39
# 7  {"requested_date": "datetime64[us]", "city": "...                 5.52
# 8  {"requested_date": "datetime64[us]", "city": "...                 0.09
# 9  {"date": "datetime64[us]", "time": "object", "...                 0.12
#
#    file_count                 updated_at                 created_at  \
# 0          18 2025-04-12 23:46:24.577568 2025-04-12 16:20:03.649771
# 1          18 2025-04-12 23:46:24.467994 2025-04-12 16:20:03.547844
# 2          18 2025-04-12 23:46:24.365032 2025-04-12 16:20:03.449528
# 3          18 2025-04-12 23:46:24.217049 2025-04-12 16:20:03.309486
# 4          18 2025-04-12 23:46:24.034897 2025-04-12 16:20:03.182500
# 5          18 2025-04-12 23:46:23.880231 2025-04-12 16:20:03.054421
# 6          18 2025-04-12 23:46:23.617671 2025-04-12 16:20:02.856602
# 7          41 2025-04-12 23:46:23.165166 2025-04-12 16:20:02.576407
# 8           8 2025-04-12 23:46:22.932314 2025-04-12 16:20:02.373351
# 9          18 2025-04-12 23:46:22.709489 2025-04-12 16:20:02.224662
#
#                         source    author
# 0    open-meteo-forecast-daily  Augustin
# 1    open-meteo-forecast-daily  Augustin
# 2  open-meteo-historical-daily  Augustin
# 3  open-meteo-historical-daily  Augustin
# 4  open-meteo-historical-daily  Augustin
# 5  open-meteo-historical-daily  Augustin
# 6  open-meteo-historical-daily  Augustin
# 7   open-meteo-forecast-hourly  Augustin
# 8    open-meteo-forecast-daily  Augustin
# 9           open-meteo-current  Augustin

# %%
#Comparating gold and silver
name_folder = 'Data/_meta/metadata_table'
my_dt = DeltaTable(name_folder).to_pandas()
my_dt = my_dt[(my_dt['layer'] == 'Gold') | (my_dt['layer'] == 'Silver')]
row_counts_per_table = pd.DataFrame({
    "layer":my_dt["layer"],
    "table_name": my_dt["table_name"],
    "table_path": my_dt["table_path"],
    "total_rows": my_dt['total_rows'],
    "rows_with_at_least_one_nulls":my_dt['rows_with_nulls'],
    "rows_duplicated":my_dt['rows_duplicated']
})

row_counts_per_table.sort_values(by='table_path').head(30)
# Out:
#      layer       table_name  \
# 9     Gold          Current
# 0     Gold          PerCity
# 1     Gold    PerCityPerDay
# 8     Gold            Daily
# 7     Gold           Hourly
# 5     Gold  PerCityPerMonth
# 4     Gold   PerCityPerYear
# 3     Gold         PerMonth
# 2     Gold          PerYear
# 6     Gold            Daily
# 13  Silver          Current
# 12  Silver            Daily
# 11  Silver           Hourly
# 10  Silver            Daily
# 15  Silver      Geolocation
# 14  Silver      WeatherCode
#
#                                            table_path  total_rows  \
# 9                         Data/Gold/OpenMeteo/Current          19
# 0   Data/Gold/OpenMeteo/Forecast/Calculations/PerCity          33
# 1   Data/Gold/OpenMeteo/Forecast/Calculations/PerC...         193
# 8                  Data/Gold/OpenMeteo/Forecast/Daily         231
# 7                 Data/Gold/OpenMeteo/Forecast/Hourly        4632
# 5   Data/Gold/OpenMeteo/Historical/Calculations/Pe...        2268
# 4   Data/Gold/OpenMeteo/Historical/Calculations/Pe...         189
# 3   Data/Gold/OpenMeteo/Historical/Calculations/Pe...         144
# 2   Data/Gold/OpenMeteo/Historical/Calculations/Pe...          12
# 6                Data/Gold/OpenMeteo/Historical/Daily       69049
# 13                      Data/Silver/OpenMeteo/Current          19
# 12               Data/Silver/OpenMeteo/Forecast/Daily         231
# 11              Data/Silver/OpenMeteo/Forecast/Hourly        4632
# 10             Data/Silver/OpenMeteo/Historical/Daily       69049
# 15           Data/Silver/OpenMeteo/Others/Geolocation          37
# 14           Data/Silver/OpenMeteo/Others/WeatherCode          28
#
#     rows_with_at_least_one_nulls  rows_duplicated
# 9                              0                0
# 0                              0                0
# 1                              0                0
# 8                              4                0
# 7                              9                0
# 5                              0                0
# 4                              0                0
# 3                              0                0
# 2                              0                0
# 6                              1                0
# 13                             0                0
# 12                             0                0
# 11                             0                0
# 10                         63939                0
# 15                             0                0
# 14                             0                0

# %%
export_metadata_to_excel(layer='Gold')
# Out:
# ✅ Métadonnées exportées avec succès dans : logs/2025-04-12/gold_metadata_20h46.xlsx
